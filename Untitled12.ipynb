# %%
# Load the model
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# Replace 'path_to_your_model.h5' with the actual path to your saved model file.
# For example, if your model is saved in the base_dir as 'my_model.h5', use:
# model = load_model(os.path.join(base_dir, 'my_model.h5'))
# If it's in a different location, provide the full path, e.g., '/home/user/models/my_model.h5'

# Assuming your model is named 'my_model.h5' and is located in the base_dir
model_path = os.path.join(base_dir, 'my_model.h5') # Construct the path to your model
model = load_model(model_path) # Load the model using the correct path

# Create test data generator
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    os.path.join(base_dir, 'test'),
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f"\n Test Accuracy: {accuracy:.2%}")
print(f" Test Loss: {loss:.4f}")

# Predict on test data
preds = model.predict(test_generator)
y_pred = np.argmax(preds, axis=1)
y_true = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# Classification report
print("\n Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion matrix
print("\n Confusion Matrix:")
print(confusion_matrix(y_true, y_pred))

# Visualize sample predictions
print("\n Sample Predictions:")
# Reset the generator to get images from the beginning
test_generator.reset()
images, labels = next(test_generator)
predictions = model.predict(images)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(labels, axis=1)

for i in range(5):
    plt.imshow(images[i])
    plt.axis('off')
    plt.title(f"True: {class_labels[true_classes[i]]} | Pred: {class_labels[predicted_classes[i]]}")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-10-3548632170.py in <cell line: 0>()
#      14 # Assuming your model is named 'my_model.h5' and is located in the base_dir
#      15 model_path = os.path.join(base_dir, 'my_model.h5') # Construct the path to your model
# ---> 16 model = load_model(model_path) # Load the model using the correct path
#      17
#      18 # Create test data generator
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     194         )
#     195     if str(filepath).endswith((".h5", ".hdf5")):
# --> 196         return legacy_h5_format.load_model_from_hdf5(
#     197             filepath, custom_objects=custom_objects, compile=compile
#     198         )
#
# ...
